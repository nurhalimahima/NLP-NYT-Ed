# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                           transcript full_name
# 1  Confederate statues are being pulled down acro...         1
# 2  Ever since George Floyd was killed by Minneapo...         2
# 3  There are videos of Eric Garner and George Flo...         3
# 4  “Stop Killing Us!” Three words, scrawled on a ...         4
# 5  A Minneapolis police officer, who was filmed k...         5
# 6  Our democracy hangs in the balance. This is no...         6
# 7  When George Floyd died under the knee of a Min...         7
# 8  Imagine that no one had shot video of George F...         8

# %%
# Extract only Ali Wong's text
Ed3_text = data.transcript.loc['3']
Ed3_text[:200]
# Out:
# 'There are videos of Eric Garner and George Floyd being choked to death by police officers while pleading for their lives. There is a video of Tamir Rice, a 12-year-old boy who was shot to death while '

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Editorial 3 routine, take a look at it
Ed3_dict = markov_chain(Ed3_text)
Ed3_dict
# Out:
# {'There': ['are', 'is', 'is', 'is'],
#  'are': ['videos', 'a', 'added', 'forced', 'doing,”', 'some'],
#  'videos': ['of', 'are', 'is', 'stack'],
#  'of': ['Eric',
#   'Tamir',
#   'Ahmaud',
#   'a',
#   'black',
#   'black',
#   'black',
#   'charred',
#   'evidence.',
#   'systemic',
#   'a',
#   'our',
#   'a',
#   'so',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Jerusalem,',
#   'the',
#   'the',
#   'song',
#   'your',
#   'those',
#   'song',
#   'Ahmaud',
#   'their',
#   'rage,',
#   'rage,',
#   'the',
#   'the',
#   'its',
#   'Jacob',
#   'Israel',
#   'the',
#   'rage',
#   'defiance',
#   'state-sponsored',
#   'the',
#   'the',
#   'forgiving',
#   'hope',
#   '“I',
#   'death',
#   'its',
#   'our',
#   'justice',
#   'black',
#   'New',
#   'the',
#   'the',
#   'letters',
#   'our'],
#  'Eric': ['Garner', 'Garner'],
#  'Garner': ['and', 'be'],
#  'and': ['George',
#   'killed',
#   'handcuffing',
#   'the',
#   'to',
#   'are',
#   'beleaguered',
#   'to',
#   'customs',
#   'dashes',
#   'brutalization',
#   'Eric',
#   'unfiltered.',
#   'the',
#   'bring',
#   'shouted',
#   'the',
#   'consume',
#   'communities.',
#   'communities.',
#   'suspicion.',
#   'reconciliation',
#   'a',
#   'Instagram.'],
#  'George': ['Floyd', 'Floyd'],
#  'Floyd': ['being', 'and'],
#  'being': ['choked'],
#  'choked': ['to'],
#  'to': ['death',
#   'death',
#   'mar',
#   'which',
#   'avoid',
#   'acknowledge',
#   'our',
#   'be',
#   'be',
#   'hunt',
#   'weaponize',
#   'destruction,',
#   'what',
#   'us.',
#   'watch',
#   'write',
#   'remember.',
#   'remember',
#   'their',
#   'say.',
#   'the',
#   'be',
#   'restore',
#   'the',
#   'hope',
#   'make',
#   'hope.',
#   'hope',
#   'spill',
#   'the',
#   'our',
#   'elude',
#   'accept',
#   'publishing',
#   'the',
#   'hear'],
#  'death': ['by', 'while', '—'],
#  'by': ['police', 'the', 'claiming', 'the'],
#  'police': ['officers', 'officer', 'officer', 'by'],
#  'officers': ['while', 'looked'],
#  'while': ['pleading', 'playing', 'out', 'three'],
#  'pleading': ['for', 'for'],
#  'for': ['their',
#   'his',
#   'nearly',
#   'vengeance',
#   'you',
#   'the',
#   'forgiveness:',
#   'they',
#   'justice.',
#   'justice',
#   'reconciliation',
#   'peace,',
#   'justice'],
#  'their': ['lives.', 'deaths?', 'composition.'],
#  'lives.': ['There', 'The'],
#  'is': ['a',
#   'a',
#   'a',
#   'not',
#   'happening',
#   'a',
#   'to',
#   'the',
#   'not',
#   'the',
#   'the',
#   'a',
#   'trauma',
#   'what',
#   'a',
#   'a',
#   'not',
#   'that',
#   'too',
#   'why',
#   'possible',
#   'what',
#   'more',
#   'a',
#   'an',
#   'the',
#   'adapted.',
#   'committed'],
#  'a': ['video',
#   '12-year-old',
#   'toy',
#   'video',
#   'run.',
#   'video',
#   'police',
#   'pool',
#   'reminder',
#   'lack',
#   'manifestation',
#   'deep',
#   'disinherited',
#   'Negro',
#   'rage',
#   'man',
#   'pickup',
#   'black',
#   'pall',
#   'religious',
#   'psalm',
#   'written',
#   'call',
#   'call',
#   'thing',
#   'light',
#   'final',
#   'false',
#   'particular',
#   'future',
#   'just',
#   'people',
#   'people',
#   'priest',
#   'diversity'],
#  'video': ['of', 'of', 'of', 'of'],
#  'Tamir': ['Rice,'],
#  'Rice,': ['a'],
#  '12-year-old': ['boy'],
#  'boy': ['who'],
#  'who': ['was',
#   'was',
#   'placed',
#   'got',
#   'tried',
#   'requested',
#   'repays',
#   'seizes',
#   'lived.'],
#  'was': ['shot', 'hunted', 'insufficient', 'never', 'threatening', 'not'],
#  'shot': ['to'],
#  'playing': ['with'],
#  'with': ['a', 'the', 'the', 'this', 'the', 'us'],
#  'toy': ['gun.'],
#  'gun.': ['There'],
#  'Ahmaud': ['Arbery,', 'Arbery,'],
#  'Arbery,': ['who', 'George'],
#  'hunted': ['and'],
#  'killed': ['while'],
#  'out': ['on', 'justice.', 'beyond'],
#  'on': ['a', 'the', 'Facebook,'],
#  'run.': ['There'],
#  'officer': ['mounting', 'who'],
#  'mounting': ['and'],
#  'handcuffing': ['Dajerria'],
#  'Dajerria': ['Becton,'],
#  'Becton,': ['15'],
#  '15': ['years'],
#  'years': ['old'],
#  'old': ['at'],
#  'at': ['the', 'a', 'the', 'the', 'Christians', 'the', 'Wheaton'],
#  'the': ['time,',
#   'smell',
#   'smiling',
#   'issue',
#   'lengths',
#   'truth.',
#   'system',
#   'powerful.',
#   'soul',
#   'time.”',
#   'focus',
#   'police',
#   'neck',
#   'vigilantes',
#   'white',
#   'police',
#   'laws',
#   'black',
#   'apathy',
#   'rage',
#   'oppressed.',
#   'most',
#   'Bible',
#   'lips',
#   'disinherited.',
#   'psalmist',
#   'one',
#   'one',
#   'rocks.”',
#   'traumatized.',
#   'aftermath',
#   'destruction',
#   'sack',
#   'city,',
#   'innocent.',
#   'murder',
#   'rage',
#   'Psalmist',
#   'families',
#   'video',
#   'other',
#   'trauma',
#   'Bible',
#   'rage',
#   'oppressed.',
#   'salvation',
#   'tribes',
#   'Gentiles,',
#   'ends',
#   'earth.”',
#   'spiritual',
#   'cross.',
#   'psalms',
#   'reality',
#   'black',
#   'lynching',
#   'lynching',
#   'cross',
#   'final',
#   'Christian,',
#   'resurrection',
#   'futility',
#   'attempt.',
#   'theological',
#   'streets?',
#   'criticism',
#   'Christian',
#   'struggle',
#   'state’s',
#   'fear',
#   'Disinherited”',
#   'streets',
#   'establishment',
#   'cost',
#   'Anglican',
#   'director',
#   'Next',
#   'author',
#   'forthcoming',
#   'editor.'],
#  'time,': ['at'],
#  'pool': ['party.'],
#  'party.': ['Visible'],
#  'Visible': ['evidence'],
#  'evidence': ['of'],
#  'black': ['suffering',
#   'lynchings.',
#   'voices',
#   'man?',
#   'man',
#   'experience?',
#   'Christian',
#   'lives,',
#   'lives.',
#   'lives'],
#  'suffering': ['is'],
#  'not': ['new.', 'silent', 'that', 'know', 'a', 'rule'],
#  'new.': ['We'],
#  'We': ['have', 'contend'],
#  'have': ['photographs', 'done', 'kept.', 'called', 'the', 'been'],
#  'photographs': ['of'],
#  'lynchings.': ['The'],
#  'The': ['screams',
#   'videos',
#   'Bible',
#   'question',
#   'question',
#   'miracle',
#   'miracle',
#   'same',
#   'cross',
#   'state',
#   'hatred',
#   'only',
#   'Times',
#   'New'],
#  'screams': ['of'],
#  'voices': ['and'],
#  'smell': ['of'],
#  'charred': ['flesh'],
#  'flesh': ['was'],
#  'insufficient': ['to'],
#  'mar': ['the'],
#  'smiling': ['poses'],
#  'poses': ['gathered'],
#  'gathered': ['’round'],
#  '’round': ['our'],
#  'our': ['corpses.',
#   'personal',
#   'rage?',
#   'enemy',
#   'friendships,',
#   'own',
#   'articles.',
#   'email:'],
#  'corpses.': ['The'],
#  'reminder': ['that'],
#  'that': ['the',
#   'would',
#   'benefits',
#   'a',
#   'she',
#   'cast',
#   'led',
#   'it',
#   'it',
#   'include',
#   'my',
#   'neither',
#   'violence',
#   'we',
#   'it',
#   'we',
#   'is'],
#  'issue': ['was'],
#  'never': ['about'],
#  'about': ['a', 'the', 'those', 'how', 'black', 'this'],
#  'lack': ['of'],
#  'evidence.': ['They'],
#  'They': ['reveal'],
#  'reveal': ['the'],
#  'lengths': ['to'],
#  'which': ['those', 'this'],
#  'those': ['in', 'videos', 'who', 'of', 'whom'],
#  'in': ['power',
#   'those',
#   'the',
#   'this',
#   'a',
#   'a',
#   'Central',
#   'the',
#   'any',
#   'time.',
#   'Luke',
#   'the',
#   'his',
#   'the',
#   'North',
#   'Hope,”'],
#  'power': ['will'],
#  'will': ['go', 'also'],
#  'go': ['to'],
#  'avoid': ['facing'],
#  'facing': ['the'],
#  'truth.': ['What'],
#  'What': ['is', 'is', 'kind'],
#  'happening': ['in'],
#  'manifestation': ['of'],
#  'systemic': ['racism'],
#  'racism': ['—'],
#  '—': ['and', 'the', 'of'],
#  'acknowledge': ['that'],
#  'would': ['call', 'the', 'be'],
#  'call': ['into', 'to', 'for'],
#  'into': ['question'],
#  'question': ['the', 'isn’t', 'is'],
#  'system': ['that'],
#  'benefits': ['the'],
#  'powerful.': ['When'],
#  'When': ['these'],
#  'these': ['videos'],
#  'stack': ['one'],
#  'one': ['upon', 'who', 'who'],
#  'upon': ['another', 'Israel’s', 'his'],
#  'another': ['and'],
#  'added': ['to'],
#  'personal': ['slights,'],
#  'slights,': ['a'],
#  'deep': ['unsettling'],
#  'unsettling': ['anger'],
#  'anger': ['rises'],
#  'rises': ['in'],
#  'soul': ['of'],
#  'disinherited': ['and'],
#  'beleaguered': ['people.'],
#  'people.': ['James'],
#  'James': ['Baldwin'],
#  'Baldwin': ['said,'],
#  'said,': ['“To'],
#  '“To': ['be'],
#  'be': ['a', 'relatively', 'in', 'in', 'tempted', 'raw', 'my', 'a', 'a', 'a'],
#  'Negro': ['in'],
#  'this': ['country', 'psalm', 'transition', 'crucified', 'essay', 'or'],
#  'country': ['and'],
#  'relatively': ['conscious'],
#  'conscious': ['is'],
#  'rage': ['almost', 'of', 'of', 'of', '(Psalm', 'upon'],
#  'almost': ['all'],
#  'all': ['the'],
#  'time.”': ['What'],
#  'focus': ['of'],
#  'rage?': ['Are'],
#  'Are': ['we', 'we', 'we', 'we', 'we'],
#  'we': ['upset',
#   'mad',
#   'enraged',
#   'frustrated',
#   'wearied',
#   'find',
#   'speak',
#   'risk',
#   'move',
#   'recognize',
#   'take',
#   'care',
#   'must'],
#  'upset': ['with'],
#  'placed': ['his'],
#  'his': ['knee',
#   'life',
#   'enemies',
#   'last.',
#   'crucifixion',
#   'opponents',
#   'classic'],
#  'knee': ['on'],
#  'neck': ['of'],
#  'man': ['pleading', 'who'],
#  'life': ['for'],
#  'nearly': ['nine'],
#  'nine': ['minutes'],
#  'minutes': ['while'],
#  'three': ['fellow', 'days'],
#  'fellow': ['officers'],
#  'looked': ['on?'],
#  'on?': ['Are'],
#  'mad': ['at'],
#  'vigilantes': ['who'],
#  'got': ['in'],
#  'pickup': ['truck'],
#  'truck': ['to'],
#  'hunt': ['down'],
#  'down': ['an', 'the'],
#  'an': ['unarmed',
#   'atrocity',
#   'expression',
#   'oppressed',
#   'assistant',
#   'Exercise'],
#  'unarmed': ['black'],
#  'man?': ['Are'],
#  'enraged': ['by'],
#  'white': ['woman'],
#  'woman': ['who'],
#  'tried': ['to'],
#  'weaponize': ['the'],
#  'claiming': ['that'],
#  'requested': ['that'],
#  'she': ['leash'],
#  'leash': ['her'],
#  'her': ['dog', 'life?'],
#  'dog': ['in'],
#  'Central': ['Park'],
#  'Park': ['was'],
#  'threatening': ['her'],
#  'life?': ['Are'],
#  'frustrated': ['by'],
#  'laws': ['and'],
#  'customs': ['that'],
#  'cast': ['a'],
#  'pall': ['over'],
#  'over': ['the'],
#  'experience?': ['Are'],
#  'wearied': ['with'],
#  'apathy': ['of'],
#  'so': ['many?'],
#  'many?': ['The'],
#  'Bible': ['is', 'comes', 'is'],
#  'silent': ['about'],
#  'oppressed.': ['One', 'The'],
#  'One': ['of'],
#  'most': ['startlingly'],
#  'startlingly': ['violent'],
#  'violent': ['passages'],
#  'passages': ['in'],
#  'comes': ['from'],
#  'from': ['the', 'an', 'the', 'vengeance.', 'which'],
#  'lips': ['of'],
#  'disinherited.': ['In'],
#  'In': ['Psalm'],
#  'Psalm': ['137', '137', '137'],
#  '137': ['the', 'is', 'is'],
#  'psalmist': ['says,'],
#  'says,': ['“Daughter', '“It'],
#  '“Daughter': ['Babylon,'],
#  'Babylon,': ['doomed'],
#  'doomed': ['to'],
#  'destruction,': ['happy'],
#  'happy': ['is'],
#  'repays': ['you'],
#  'you': ['according', 'have', 'write', 'are', 'to', 'a', 'think'],
#  'according': ['to'],
#  'what': ['you', 'kind', 'they', 'separates', 'you'],
#  'done': ['to'],
#  'us.': ['Happy', 'Too'],
#  'Happy': ['is'],
#  'seizes': ['your'],
#  'your': ['infants', 'wife,', 'child,', 'neighbor?'],
#  'infants': ['and'],
#  'dashes': ['them'],
#  'them': ['against'],
#  'against': ['the'],
#  'rocks.”': ['How'],
#  'How': ['can'],
#  'can': ['wishing'],
#  'wishing': ['such'],
#  'such': ['an'],
#  'atrocity': ['be'],
#  'any': ['sense', 'of'],
#  'sense': ['a', 'of'],
#  'religious': ['text?'],
#  'text?': ['Psalm'],
#  'psalm': ['of', 'is'],
#  'traumatized.': ['It'],
#  'It': ['depicts', 'would', 'is', 'was', 'empties', 'is', 'damages'],
#  'depicts': ['the'],
#  'aftermath': ['of'],
#  'destruction': ['of'],
#  'Jerusalem,': ['the'],
#  'sack': ['of'],
#  'city,': ['sexual'],
#  'sexual': ['assault'],
#  'assault': ['and'],
#  'brutalization': ['of'],
#  'innocent.': ['What'],
#  'kind': ['of', 'of'],
#  'song': ['do', 'would'],
#  'do': ['you', 'not'],
#  'write': ['if', 'after'],
#  'if': ['you', 'we'],
#  'forced': ['to'],
#  'watch': ['the'],
#  'murder': ['of'],
#  'wife,': ['your'],
#  'child,': ['your'],
#  'neighbor?': ['Psalm'],
#  'trauma': ['literature,', 'that'],
#  'literature,': ['the'],
#  'lived.': ['The'],
#  'isn’t': ['why'],
#  'why': ['the', 'the'],
#  'Psalmist': ['wrote'],
#  'wrote': ['this.', 'in'],
#  'this.': ['The'],
#  'families': ['of', 'and'],
#  'tempted': ['to'],
#  'after': ['watching', 'his', 'the'],
#  'watching': ['the'],
#  'deaths?': ['It'],
#  'raw': ['and'],
#  'unfiltered.': ['But'],
#  'But': ['more', 'justice'],
#  'more': ['than', 'to', 'than'],
#  'than': ['an', 'mutual'],
#  'expression': ['of'],
#  'rage,': ['this', 'require', 'once'],
#  'written': ['record'],
#  'record': ['in'],
#  'time.': ['It'],
#  'remember.': ['This'],
#  'This': ['psalm,'],
#  'psalm,': ['and'],
#  'other': ['psalms'],
#  'psalms': ['of', 'of'],
#  'require': ['us'],
#  'us': ['to', 'make', 'to'],
#  'remember': ['the'],
#  'led': ['to'],
#  'composition.': ['The'],
#  'miracle': ['of', 'is'],
#  'it': ['records', 'has', 'does', 'seems'],
#  'records': ['the'],
#  'has': ['more', 'always'],
#  'say.': ['The'],
#  'same': ['texts'],
#  'texts': ['that'],
#  'include': ['a'],
#  'vengeance': ['upon'],
#  'Israel’s': ['enemies'],
#  'enemies': ['look', 'and'],
#  'look': ['to'],
#  'salvation': ['of', 'may'],
#  'its': ['oppressors.', 'power.', 'intended'],
#  'oppressors.': ['Isaiah'],
#  'Isaiah': ['49'],
#  '49': ['says,'],
#  '“It': ['is'],
#  'too': ['small', 'quickly'],
#  'small': ['a'],
#  'thing': ['for'],
#  'my': ['servant', 'salvation'],
#  'servant': ['to'],
#  'restore': ['the'],
#  'tribes': ['of'],
#  'Jacob': ['and'],
#  'bring': ['back'],
#  'back': ['those'],
#  'Israel': ['I'],
#  'I': ['have', 'will'],
#  'kept.': ['I'],
#  'also': ['make'],
#  'make': ['you', 'this', 'sense'],
#  'light': ['for'],
#  'Gentiles,': ['that'],
#  'may': ['reach'],
#  'reach': ['to'],
#  'ends': ['of'],
#  'earth.”': ['For'],
#  'For': ['Christians,', 'the'],
#  'Christians,': ['rage'],
#  '(Psalm': ['137)'],
#  '137)': ['must'],
#  'must': ['eventually', 'be', 'be'],
#  'eventually': ['give'],
#  'give': ['way'],
#  'way': ['to'],
#  'hope': ['(Isaiah', 'when', 'because', 'doesn’t'],
#  '(Isaiah': ['49).'],
#  '49).': ['And'],
#  'And': ['we', 'Jesus’', 'because', 'here’s'],
#  'find': ['the'],
#  'spiritual': ['resources'],
#  'resources': ['to', 'to'],
#  'transition': ['at'],
#  'cross.': ['Jesus'],
#  'Jesus': ['could', 'experienced'],
#  'could': ['have', 'stop'],
#  'called': ['down', 'for'],
#  'shouted': ['a'],
#  'final': ['word', 'say'],
#  'word': ['of'],
#  'defiance': ['before'],
#  'before': ['he'],
#  'he': ['breathed', 'called', 'says', 'serves'],
#  'breathed': ['his'],
#  'last.': ['Instead'],
#  'Instead': ['he'],
#  'forgiveness:': ['“Father,'],
#  '“Father,': ['forgive'],
#  'forgive': ['them,'],
#  'them,': ['for'],
#  'they': ['do', 'are'],
#  'know': ['what'],
#  'doing,”': ['he'],
#  'says': ['in'],
#  'Luke': ['23.'],
#  '23.': ['It'],
#  'false': ['reconciliation:'],
#  'reconciliation:': ['Jesus'],
#  'experienced': ['the'],
#  'reality': ['of'],
#  'state-sponsored': ['terror.'],
#  'terror.': ['That'],
#  'That': ['is'],
#  'Christian': ['has', 'from'],
#  'always': ['felt'],
#  'felt': ['a'],
#  'particular': ['kinship'],
#  'kinship': ['with'],
#  'crucified': ['king'],
#  'king': ['from'],
#  'oppressed': ['ethnic'],
#  'ethnic': ['group.'],
#  'group.': ['The'],
#  'cross': ['helps', 'have'],
#  'helps': ['us'],
#  'lynching': ['tree.', 'tree'],
#  'tree.': ['And'],
#  'Jesus’': ['resurrection', 'profound'],
#  'resurrection': ['three', 'makes'],
#  'days': ['after'],
#  'crucifixion': ['shows'],
#  'shows': ['that'],
#  'neither': ['the'],
#  'tree': ['nor'],
#  'nor': ['the'],
#  'say': ['about'],
#  'whom': ['God'],
#  'God': ['values.'],
#  'values.': ['The'],
#  'state': ['thought'],
#  'thought': ['that'],
#  'violence': ['could'],
#  'stop': ['God’s'],
#  'God’s': ['purposes.'],
#  'purposes.': ['For'],
#  'Christian,': ['the'],
#  'makes': ['clear'],
#  'clear': ['the'],
#  'futility': ['of'],
#  'attempt.': ['Further,'],
#  'Further,': ['Jesus’'],
#  'profound': ['act'],
#  'act': ['of'],
#  'forgiving': ['his'],
#  'opponents': ['provides'],
#  'provides': ['me'],
#  'me': ['with'],
#  'theological': ['resources'],
#  'hope.': ['Dare'],
#  'Dare': ['we'],
#  'speak': ['of'],
#  'when': ['chants', 'it'],
#  'chants': ['of'],
#  '“I': ['can’t'],
#  'can’t': ['breathe”'],
#  'breathe”': ['echo'],
#  'echo': ['in'],
#  'streets?': ['Do'],
#  'Do': ['we'],
#  'risk': ['the'],
#  'criticism': ['commonly'],
#  'commonly': ['levied'],
#  'levied': ['at'],
#  'Christians': ['that', 'contend', 'should'],
#  'move': ['too'],
#  'quickly': ['to'],
#  'because': ['faith', 'we', 'there', 'Christians'],
#  'faith': ['pacifies?'],
#  'pacifies?': ['Resurrection'],
#  'Resurrection': ['hope'],
#  'doesn’t': ['remove'],
#  'remove': ['the'],
#  'struggle': ['for'],
#  'justice.': ['It', 'It'],
#  'empties': ['the'],
#  'state’s': ['greatest'],
#  'greatest': ['weapon'],
#  'weapon': ['—'],
#  'fear': ['of'],
#  'power.': ['Hope'],
#  'Hope': ['is'],
#  'possible': ['if'],
#  'recognize': ['that'],
#  'does': ['not'],
#  'rule': ['out'],
#  'separates': ['justice'],
#  'justice': ['from', 'because', 'because', 'and', 'even'],
#  'vengeance.': ['Howard'],
#  'Howard': ['Thurman'],
#  'Thurman': ['wrote'],
#  'classic': ['work'],
#  'work': ['“Jesus'],
#  '“Jesus': ['and'],
#  'Disinherited”': ['about'],
#  'how': ['rage,'],
#  'once': ['unleashed,'],
#  'unleashed,': ['tends'],
#  'tends': ['to'],
#  'spill': ['out'],
#  'beyond': ['its'],
#  'intended': ['target'],
#  'target': ['and'],
#  'consume': ['everything.'],
#  'everything.': ['The'],
#  'hatred': ['of'],
#  'enemy': ['that'],
#  'take': ['to'],
#  'streets': ['returns'],
#  'returns': ['with'],
#  'friendships,': ['marriages'],
#  'marriages': ['and'],
#  'communities.': ['It', 'We'],
#  'damages': ['our'],
#  'own': ['souls.'],
#  'souls.': ['Christians'],
#  'contend': ['for', 'for'],
#  'care': ['about'],
#  'lives,': ['families'],
#  'reconciliation': ['after', 'cannot'],
#  'establishment': ['of'],
#  'there': ['must'],
#  'future': ['that', 'is'],
#  'mutual': ['contempt'],
#  'contempt': ['and'],
#  'suspicion.': ['But'],
#  'cannot': ['come'],
#  'come': ['at'],
#  'cost': ['of'],
#  'only': ['peaceful'],
#  'peaceful': ['future'],
#  'just': ['future.'],
#  'future.': ['And'],
#  'should': ['be'],
#  'people': ['for', 'for'],
#  'peace,': ['we'],
#  'even': ['when'],
#  'seems': ['ever'],
#  'ever': ['to'],
#  'elude': ['us.'],
#  'Too': ['many'],
#  'many': ['black'],
#  'lives': ['have'],
#  'been': ['lost'],
#  'lost': ['to'],
#  'accept': ['anything'],
#  'anything': ['else.'],
#  'else.': ['Esau'],
#  'Esau': ['McCaulley'],
#  'McCaulley': ['(@esaumccaulley)'],
#  '(@esaumccaulley)': ['is'],
#  'assistant': ['professor'],
#  'professor': ['of'],
#  'New': ['Testament', 'York'],
#  'Testament': ['at'],
#  'Wheaton': ['College'],
#  'College': ['and'],
#  'priest': ['in'],
#  'Anglican': ['Church'],
#  'Church': ['in'],
#  'North': ['America,'],
#  'America,': ['where'],
#  'where': ['he'],
#  'serves': ['as'],
#  'as': ['the', 'an'],
#  'director': ['of'],
#  'Next': ['Generation'],
#  'Generation': ['Leadership'],
#  'Leadership': ['Initiative.'],
#  'Initiative.': ['He'],
#  'He': ['is'],
#  'author': ['of'],
#  'forthcoming': ['book'],
#  'book': ['“Reading'],
#  '“Reading': ['While'],
#  'While': ['Black:'],
#  'Black:': ['African'],
#  'African': ['American'],
#  'American': ['Biblical'],
#  'Biblical': ['Interpretation'],
#  'Interpretation': ['as'],
#  'Exercise': ['in'],
#  'Hope,”': ['from'],
#  'essay': ['is'],
#  'adapted.': ['The'],
#  'Times': ['is', 'Opinion'],
#  'committed': ['to'],
#  'publishing': ['a'],
#  'diversity': ['of'],
#  'letters': ['to'],
#  'editor.': ['We’d'],
#  'We’d': ['like'],
#  'like': ['to'],
#  'hear': ['what'],
#  'think': ['about'],
#  'or': ['any'],
#  'articles.': ['Here'],
#  'Here': ['are'],
#  'some': ['tips.'],
#  'tips.': ['And'],
#  'here’s': ['our'],
#  'email:': ['letters@nytimes.com.'],
#  'letters@nytimes.com.': ['Follow'],
#  'Follow': ['The'],
#  'York': ['Times'],
#  'Opinion': ['section'],
#  'section': ['on'],
#  'Facebook,': ['Twitter'],
#  'Twitter': ['(@NYTopinion)'],
#  '(@NYTopinion)': ['and']}

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(Ed3_dict)
# Out:
# 'Group. The question the editor. We’d like to elude us. Happy is what separates justice.'
